# %%
#Aaron Rothleder
#Salk Institute
#1 May, 2017

#File: Variance_Manipulation.pynb
#Description:

# %%
# Imports
#  Note: these are all the imports you need! Do not import any other functions / packages
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read in files
df1 = pd.read_csv("ex_hTF_0_100.csv")
df2 = pd.read_csv("ex_hTF_101_200.csv")
df3 = pd.read_csv("ex_hTF_201_300.csv")
df4 = pd.read_csv("ex_hTF_301_400.csv")
df5 = pd.read_csv("ex_hTF_401_500.csv")
df6 = pd.read_csv("ex_hTF_501_600.csv")
df7 = pd.read_csv("ex_hTF_601_700.csv")
df8 = pd.read_csv("ex_hTF_701_800.csv")
df9 = pd.read_csv("ex_hTF_801_900.csv")
df10 = pd.read_csv("ex_hTF_901_1000.csv")
df11 = pd.read_csv("ex_hTF_1001_1100.csv")
df12 = pd.read_csv("ex_hTF_1101_1200.csv")
df13 = pd.read_csv("ex_hTF_1201_1300.csv")
df14 = pd.read_csv("ex_hTF_1301_1400.csv")
df15 = pd.read_csv("ex_hTF_1401_1500.csv")
df16 = pd.read_csv("ex_hTF_1501_1600.csv")
df17 = pd.read_csv("ex_hTF_1601_1700.csv")
df18 = pd.read_csv("ex_hTF_1701_1800.csv")
df19 = pd.read_csv("ex_hTF_1801_1900.csv")
df20 = pd.read_csv("ex_hTF_1901_2000.csv")
df21 = pd.read_csv("ex_hTF_2001_2100.csv")
df22 = pd.read_csv("ex_hTF_2101_2200.csv")
df23 = pd.read_csv("ex_hTF_2201_2300.csv")
df24 = pd.read_csv("ex_hTF_2301_2400.csv")
df25 = pd.read_csv("ex_hTF_2401_2522.csv")

# %%
#merge rest of Range_Finder_Exfiles onto result

result = df1.append([df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25])
#print(result)

# %%
#replace all empty lists with NaN and push to new CSV
result = result.replace('[]',np.nan)
result.to_csv("ex_hTF_Final.csv")
print(result)
# Out:
#      Domain end (aa)  Domain length (aa)  Domain start (aa)  \
# 0                436                 212                224
# 1                562                 108                454
# 2                436                 212                224
# 3                562                 108                454
# 4                389                  64                325
# 5                385                  56                329
# 6                544                  18                526
# 7                393                  69                324
# 8                250                  20                230
# 9                 99                  18                 81
# 10               139                  39                100
# 11               155                  14                141
# 12               223                  17                206
# 13               255                  31                224
# 14               288                  20                268
# ...

# %%
corrs = result.corr(method = 'pearson')
#print(corrs)
fd = pd.scatter_matrix(result)
